# %%
from PIL import Image
import matplotlib.pyplot as plt

# Paths to your images
paths = ["../../../../datasets/flat_dataset/formacao_2_00008.jpg", 
"../../../../datasets/flat_dataset/formacao_2_00053.jpg", 
"../../../../datasets/flat_dataset/formacao_2_00123.jpg",
"../../../../datasets/flat_dataset/qc2_qd1_10x_formacao_00003.jpg", 
"../../../../datasets/flat_dataset/qc2_qd1_10x_formacao2_00004.jpg", 
"../../../../datasets/flat_dataset/qc2_qd1_10x_formacao2_00006.jpg"]

images = [Image.open(p) for p in paths]

fig, axes = plt.subplots(2, 3, figsize=(12, 8))

for ax, img, path in zip(axes.flat, images, paths):
    ax.imshow(img)
    ax.axis("off")

plt.tight_layout()
plt.show()
